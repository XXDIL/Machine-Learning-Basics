# %% [markdown]
# ### Import the header files

# %%
import pandas as pd

# %% [markdown]
# ### Extract data from the csv file

# %%
df = pd.read_csv('DATA.csv', lineterminator='\n')

# %% [markdown]
# ### Data grouped by country then by city.

# %%
G = df.groupby(['Country', 'City'])
G.first()
# Out:
#                              Unnamed: 0  \
# Country       City
# Australia     Agnes Water          1247
#               Airlie Beach          772
#               Alice Springs         409
#               Appin                 974
#               Bonville              292
# ...                                 ...
# United States Sugar Hill            996
#               Tuolumne              572
#               Warrington             53
#               Williams               39
#               Williamsburg           64
#
#                                                                         Name  \
# Country       City
# Australia     Agnes Water              1770 Lagoons Central Apartment Resort
#               Airlie Beach                               Nomads Airlie Beach
#               Alice Springs                       Desert Palms Alice Springs
#               Appin                                      Appin Village Motel
# ...
